# %%
# Import date

from datetime import date

# Create our dates
d1 = date(2017, 11, 5)
d2 = date(2017, 12, 4)
l = [d1, d2]
print(min(l))
# Out:
# 2017-11-05

# %%
print(l[0].day)
# Out:
# 5

# %%
from datetime import timedelta
