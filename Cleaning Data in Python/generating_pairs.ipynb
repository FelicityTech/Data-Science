# %% [markdown]
# #### Record Linkage

# %%
pip install recordlinkage
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/926.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/926.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/926.9 kB ? eta -:--:--
#    ---------------------------------------- 926.9/926.9 kB 2.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import recordlinkage
import recordlinkage

# Create indexing object
indexer = recordlinkage.Index()

# Genrate pairsl blocked on state
indexer.block('state')
pairs = indexer.index(census_A, census_B)

print(pairs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 # Genrate pairsl blocked on state
#       8 indexer.block('state')
# ----> 9 pairs = indexer.index(census_A, census_B)
#      11 print(pairs)
#
# NameError: name 'census_A' is not defined

# %%
# Generate the pairs
pairs = indexer.index(census_A, census_B)
# Create a Compare object
compare_cl = recordlinkage.Compare()

# Find exact matches for pairs of date_of_birth and state
compare_cl.exact('date_of_birth', 'date_of_birth', label='date_of_birth')
compare_cl.exact('state', 'state', label='state')

# Find similar matches for pairs of surname and address_1 using string similarity
compare_cl.string('surname', 'surname', threshold=0.85, label='surname')
compare_cl.string('address_1', 'address_1', threshold=0.85, label='address_1')

# Find matches
potential_matches = compare_cl.compute(pairs, consus_A, census_B)
print(potential_matches)

# Finding the only pairs we want
pontential_matches[potential_matches.sum(axis = 1) => 2]

# %% [markdown]
# ### Exercise

# %%
# Iterate through categories
for cuisine in categories:  
  # Your previous code should be placed here
  # For example, create a list of matches
  matches = process.extract(cuisine, restaurants['cuisine_type'], limit=len(restaurants.cuisine_type))
  
  # Iterate through the list of matches
  for match in matches:
    # Check the similarity score
    if match[1] >= 80:
      # Update the cuisine_type
      restaurants.loc[restaurants['cuisine_type'] == match[0]] = cuisine
# Inspect the final result
print(restaurants['cuisine_type'].unique())

# %%
# Create a comparison object
comp_cl = recordlinkage.Compare()

# %%
# Create a comparison object
comp_cl = recordlinkage.Compare()

# Find exact matches on city, cuisine_types - 
comp_cl.exact('city', 'city', label='city')
comp_cl.exact('cuisine_type', 'cuisine_type', label='cuisine_type')

# Find similar matches of rest_name
comp_cl.string('rest_name', 'rest_name', label='name', threshold = 0.8) 

# Get potential matches and print
potential_matches = comp_cl.compute(pairs, restaurants, restaurants_new)
print(potential_matches)
